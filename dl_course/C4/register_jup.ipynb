# %% [markdown]
# # 如何将conda的python环境加入jupyter的kernel

# %% [markdown]
# ## 第一步 进入环境

# %% [markdown]
# conda activate env

# %% [markdown]
# ## 第二步 安装 ipykernel

# %% [markdown]
# pip install ipykernel

# %% [markdown]
# ## 第三步 注册到 Jupyter

# %% [markdown]
# python -m ipykernel install --user --name=myenv --display-name "Python (myenv)"
